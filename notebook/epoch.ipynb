# %%
import mne
import pandas as pd
import numpy as np
import os

def process_subject_epochs(sub_id, run_ids, raw_base_dir, stim_base_dir, out_base_dir):
    """
    切出每個 run 的 epoch + metadata，存檔（會自動 skip 缺檔案）
    
    sub_id: e.g. 'sub-01'
    run_ids: e.g. [1, 2, 3, 4, ...]
    raw_base_dir: 原始 raw 的資料夾
    stim_base_dir: stimulus table 的資料夾
    out_base_dir: 存檔資料夾
    """
    for run_id in run_ids:
        print(f'Processing {sub_id}, run {run_id}...')
        
        # 檢查 raw 檔案是否存在
        meg_path = f"{raw_base_dir}/{sub_id}/MEG/{sub_id}_task-RDR_run-{run_id}_meg.fif"
        if not os.path.exists(meg_path):
            print(f'⚠️ Skipping run {run_id}: raw file not found → {meg_path}')
            continue

        # 檢查 stim table 是否存在
        stim_path = f"{stim_base_dir}/story_{run_id}_stimulus_table.csv"
        if not os.path.exists(stim_path):
            print(f'⚠️ Skipping run {run_id}: stimulus table not found → {stim_path}')
            continue

        # === 讀 raw ===
        raw = mne.io.read_raw_fif(meg_path, preload=True)
        sfreq = raw.info['sfreq']

        # === 讀 stim csv 並過濾 POS ===
        df = pd.read_csv(stim_path)
        df = df[df['pos'].isin(['NN', 'VV'])].copy()
        if df.empty:
            print(f'⚠️ Skipping run {run_id}: no NN/VV entries in stimulus table.')
            continue

        # === 建 events ===
        event_samples = (df['word_onset_sec'] * sfreq).round().astype(int).to_numpy()
        event_ids = df['pos'].map({'NN': 1, 'VV': 2}).to_numpy()
        events = np.column_stack([event_samples, np.zeros_like(event_samples), event_ids])

        event_id = {'NN': 1, 'VV': 2}

        # === 切 epoch ===
        try:
            epochs = mne.Epochs(
                raw, events, event_id=event_id,
                tmin=-0.2, tmax=0.8,
                baseline=None,
                picks='meg',
                preload=True
            )
        except Exception as e:
            print(f'❌ Error processing run {run_id}: {e}')
            continue

        # === metadata dataframe ===
        meta_df = pd.DataFrame({
            'word': df['word'].values,
            'pos': df['pos'].values,
            'word_freq_log': df['word_freq_log'].values,
            'word_onset_sec': df['word_onset_sec'].values
        })

        # === 存檔 ===
        out_dir = f'{out_base_dir}/{sub_id}_run-{run_id}'
        os.makedirs(out_dir, exist_ok=True)

        epochs.save(f'{out_dir}/{sub_id}_run-{run_id}_epo.fif', overwrite=True)
        meta_df.to_csv(f'{out_dir}/{sub_id}_run-{run_id}_meta.csv', index=False)

        print(f'✅ {sub_id}, run {run_id} done.\n')

# %%
# 設定參數
sub_id = 'sub-01'
#run_ids = [1, 2, 3, 4]  # 你可以改成 list(range(1,61)) → 一鍵處理 60 runs
run_ids =list(range(1,61))
raw_base_dir = '../SMN4Lang_data/ds004078/derivatives/preprocessed_data'
stim_base_dir = 'StimulusTables'
out_base_dir = 'PreprocessedEpochs'

# 執行
process_subject_epochs(sub_id, run_ids, raw_base_dir, stim_base_dir, out_base_dir)
# Out:
# Processing sub-01, run 1...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-1_meg.fif...
#     Range : 13000 ... 458999 =     13.000 ...   458.999 secs
# Ready.
# Reading 0 ... 445999  =      0.000 ...   445.999 secs...
# Not setting metadata
# 411 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 411 events and 1001 original time points ...
# 20 bad epochs dropped
# → sub-01, run 1 done.
#
# Processing sub-01, run 2...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-2_meg.fif...
#     Range : 8000 ... 405999 =      8.000 ...   405.999 secs
# Ready.
# Reading 0 ... 397999  =      0.000 ...   397.999 secs...
# Not setting metadata
# 381 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 381 events and 1001 original time points ...
# 10 bad epochs dropped
# → sub-01, run 2 done.
#
# Processing sub-01, run 3...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-3_meg.fif...
#     Range : 6000 ... 371999 =      6.000 ...   371.999 secs
# Ready.
# Reading 0 ... 365999  =      0.000 ...   365.999 secs...
# Not setting metadata
# 402 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 402 events and 1001 original time points ...
# 7 bad epochs dropped
# → sub-01, run 3 done.
#
# Processing sub-01, run 4...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-4_meg.fif...
#     Range : 6000 ... 368999 =      6.000 ...   368.999 secs
# Ready.
# Reading 0 ... 362999  =      0.000 ...   362.999 secs...
# Not setting metadata
# 419 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 419 events and 1001 original time points ...
# 10 bad epochs dropped
# → sub-01, run 4 done.
#
# Processing sub-01, run 5...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-5_meg.fif...
#     Range : 6000 ... 369999 =      6.000 ...   369.999 secs
# Ready.
# Reading 0 ... 363999  =      0.000 ...   363.999 secs...
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 349 events and 1001 original time points ...
# 13 bad epochs dropped
# → sub-01, run 5 done.
#
# Processing sub-01, run 6...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-6_meg.fif...
#     Range : 6000 ... 338999 =      6.000 ...   338.999 secs
# Ready.
# Reading 0 ... 332999  =      0.000 ...   332.999 secs...
# Not setting metadata
# 333 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 333 events and 1001 original time points ...
# 6 bad epochs dropped
# → sub-01, run 6 done.
#
# Processing sub-01, run 7...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-7_meg.fif...
#     Range : 9000 ... 341999 =      9.000 ...   341.999 secs
# Ready.
# Reading 0 ... 332999  =      0.000 ...   332.999 secs...
# Not setting metadata
# 344 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 344 events and 1001 original time points ...
# 11 bad epochs dropped
# → sub-01, run 7 done.
#
# Processing sub-01, run 8...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-8_meg.fif...
#     Range : 6000 ... 302999 =      6.000 ...   302.999 secs
# Ready.
# Reading 0 ... 296999  =      0.000 ...   296.999 secs...
# Not setting metadata
# 338 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 338 events and 1001 original time points ...
# 6 bad epochs dropped
# → sub-01, run 8 done.
#
# Processing sub-01, run 9...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-9_meg.fif...
#     Range : 21000 ... 305999 =     21.000 ...   305.999 secs
# Ready.
# Reading 0 ... 284999  =      0.000 ...   284.999 secs...
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 1001 original time points ...
# 25 bad epochs dropped
# → sub-01, run 9 done.
#
# Processing sub-01, run 10...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-10_meg.fif...
#     Range : 8000 ... 288999 =      8.000 ...   288.999 secs
# Ready.
# Reading 0 ... 280999  =      0.000 ...   280.999 secs...
# Not setting metadata
# 318 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 318 events and 1001 original time points ...
# 21 bad epochs dropped
# → sub-01, run 10 done.
#
# Processing sub-01, run 11...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-11_meg.fif...
#     Range : 7000 ... 434999 =      7.000 ...   434.999 secs
# Ready.
# Reading 0 ... 427999  =      0.000 ...   427.999 secs...
# Not setting metadata
# 426 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 426 events and 1001 original time points ...
# 9 bad epochs dropped
# → sub-01, run 11 done.
#
# Processing sub-01, run 12...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-12_meg.fif...
#     Range : 6000 ... 394999 =      6.000 ...   394.999 secs
# Ready.
# Reading 0 ... 388999  =      0.000 ...   388.999 secs...
# Not setting metadata
# 444 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 444 events and 1001 original time points ...
# 9 bad epochs dropped
# → sub-01, run 12 done.
#
# Processing sub-01, run 13...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-13_meg.fif...
#     Range : 6000 ... 375999 =      6.000 ...   375.999 secs
# Ready.
# Reading 0 ... 369999  =      0.000 ...   369.999 secs...
# Not setting metadata
# 361 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 361 events and 1001 original time points ...
# 5 bad epochs dropped
# → sub-01, run 13 done.
#
# Processing sub-01, run 14...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-14_meg.fif...
#     Range : 6000 ... 353999 =      6.000 ...   353.999 secs
# Ready.
# Reading 0 ... 347999  =      0.000 ...   347.999 secs...
# Not setting metadata
# 426 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 426 events and 1001 original time points ...
# 11 bad epochs dropped
# → sub-01, run 14 done.
#
# Processing sub-01, run 15...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-15_meg.fif...
#     Range : 6000 ... 351999 =      6.000 ...   351.999 secs
# Ready.
# Reading 0 ... 345999  =      0.000 ...   345.999 secs...
# Not setting metadata
# 362 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 362 events and 1001 original time points ...
# 7 bad epochs dropped
# → sub-01, run 15 done.
#
# Processing sub-01, run 16...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-16_meg.fif...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       7 out_base_dir = 'PreprocessedEpochs'
#       9 # 執行
# ---> 10 process_subject_epochs(sub_id, run_ids, raw_base_dir, stim_base_dir, out_base_dir)
#
# Cell In[1], line 21, in process_subject_epochs(sub_id, run_ids, raw_base_dir, stim_base_dir, out_base_dir)
#      19 # === 讀 raw ===
#      20 meg_path = f"{raw_base_dir}/{sub_id}/MEG/{sub_id}_task-RDR_run-{run_id}_meg.fif"
# ---> 21 raw = mne.io.read_raw_fif(meg_path, preload=True)
#      22 sfreq = raw.info['sfreq']
#      24 # === 讀 stimulus table ===
#
# File ~/miniconda3/envs/meg-analysis-env/lib/python3.10/site-packages/mne/io/fiff/raw.py:543, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     502 @fill_doc
#     503 def read_raw_fif(
#     504     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     505 ) -> Raw:
#     506     """Reader function for Raw FIF data.
#     507
#     508     Parameters
#    (...)
#     541     are updated accordingly.
#     542     """
# --> 543     return Raw(
#     544         fname=fname,
#     545         allow_maxshield=allow_maxshield,
#     546         preload=preload,
#     547         verbose=verbose,
#     548         on_split_missing=on_split_missing,
#     549     )
#
# File <decorator-gen-204>:12, in __init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#
# File ~/miniconda3/envs/meg-analysis-env/lib/python3.10/site-packages/mne/io/fiff/raw.py:103, in Raw.__init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#     101 next_fname = fname
#     102 while next_fname is not None:
# --> 103     raw, next_fname, buffer_size_sec = self._read_raw_file(
#     104         next_fname, allow_maxshield, preload, do_check_ext
#     105     )
#     106     do_check_ext = False
#     107     raws.append(raw)
#
# File <decorator-gen-205>:12, in _read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#
# File ~/miniconda3/envs/meg-analysis-env/lib/python3.10/site-packages/mne/io/fiff/raw.py:198, in Raw._read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#     196         check_fname(fname, "raw", endings)
#     197     # filename
# --> 198     fname = _check_fname(fname, "read", True, "fname")
#     199     whole_file = preload if fname.suffix == ".gz" else False
#     200 else:
#     201     # file-like
#
# File <decorator-gen-0>:12, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#
# File ~/miniconda3/envs/meg-analysis-env/lib/python3.10/site-packages/mne/utils/check.py:302, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#     300             raise PermissionError(f"{name} does not have read permissions: {fname}")
#     301 elif must_exist:
# --> 302     raise FileNotFoundError(f'{name} does not exist: "{fname}"')
#     304 return fname
#
# FileNotFoundError: fname does not exist: "/Users/meguser/Desktop/Project for Brainhack/domybest/../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-16_meg.fif"

# %%
sub_id = 'sub-01'
run_ids = list(range(16, 61))  # or any subset you want
raw_base_dir = '../SMN4Lang_data/ds004078/derivatives/preprocessed_data'
stim_base_dir = 'StimulusTables'
out_base_dir = 'PreprocessedEpochs'

process_subject_epochs(sub_id, run_ids, raw_base_dir, stim_base_dir, out_base_dir)
# Out:
# Processing sub-01, run 16...
# ⚠️ Skipping run 16: raw file not found → ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-16_meg.fif
# Processing sub-01, run 17...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-17_meg.fif...
#     Range : 8000 ... 328999 =      8.000 ...   328.999 secs
# Ready.
# Reading 0 ... 320999  =      0.000 ...   320.999 secs...
# Not setting metadata
# 355 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 355 events and 1001 original time points ...
# 11 bad epochs dropped
# ✅ sub-01, run 17 done.
#
# Processing sub-01, run 18...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-18_meg.fif...
#     Range : 7000 ... 314999 =      7.000 ...   314.999 secs
# Ready.
# Reading 0 ... 307999  =      0.000 ...   307.999 secs...
# Not setting metadata
# 305 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 305 events and 1001 original time points ...
# 7 bad epochs dropped
# ✅ sub-01, run 18 done.
#
# Processing sub-01, run 19...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-19_meg.fif...
#     Range : 6000 ... 302999 =      6.000 ...   302.999 secs
# Ready.
# Reading 0 ... 296999  =      0.000 ...   296.999 secs...
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 349 events and 1001 original time points ...
# 11 bad epochs dropped
# ✅ sub-01, run 19 done.
#
# Processing sub-01, run 20...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-20_meg.fif...
#     Range : 7000 ... 292999 =      7.000 ...   292.999 secs
# Ready.
# Reading 0 ... 285999  =      0.000 ...   285.999 secs...
# Not setting metadata
# 256 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 256 events and 1001 original time points ...
# 11 bad epochs dropped
# ✅ sub-01, run 20 done.
#
# Processing sub-01, run 21...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-21_meg.fif...
#     Range : 6000 ... 445999 =      6.000 ...   445.999 secs
# Ready.
# Reading 0 ... 439999  =      0.000 ...   439.999 secs...
# Not setting metadata
# 416 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 416 events and 1001 original time points ...
# 8 bad epochs dropped
# ✅ sub-01, run 21 done.
#
# Processing sub-01, run 22...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-22_meg.fif...
#     Range : 11000 ... 406999 =     11.000 ...   406.999 secs
# Ready.
# Reading 0 ... 395999  =      0.000 ...   395.999 secs...
# Not setting metadata
# 366 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 366 events and 1001 original time points ...
# 12 bad epochs dropped
# ✅ sub-01, run 22 done.
#
# Processing sub-01, run 23...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-23_meg.fif...
#     Range : 6000 ... 363999 =      6.000 ...   363.999 secs
# Ready.
# Reading 0 ... 357999  =      0.000 ...   357.999 secs...
# Not setting metadata
# 326 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 326 events and 1001 original time points ...
# 7 bad epochs dropped
# ✅ sub-01, run 23 done.
#
# Processing sub-01, run 24...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-24_meg.fif...
#     Range : 7000 ... 357999 =      7.000 ...   357.999 secs
# Ready.
# Reading 0 ... 350999  =      0.000 ...   350.999 secs...
# Not setting metadata
# 373 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 373 events and 1001 original time points ...
# 4 bad epochs dropped
# ✅ sub-01, run 24 done.
#
# Processing sub-01, run 25...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-25_meg.fif...
#     Range : 8000 ... 337999 =      8.000 ...   337.999 secs
# Ready.
# Reading 0 ... 329999  =      0.000 ...   329.999 secs...
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 325 events and 1001 original time points ...
# 8 bad epochs dropped
# ✅ sub-01, run 25 done.
#
# Processing sub-01, run 26...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-26_meg.fif...
#     Range : 21000 ... 355999 =     21.000 ...   355.999 secs
# Ready.
# Reading 0 ... 334999  =      0.000 ...   334.999 secs...
# Not setting metadata
# 318 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 318 events and 1001 original time points ...
# 28 bad epochs dropped
# ✅ sub-01, run 26 done.
#
# Processing sub-01, run 27...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-27_meg.fif...
#     Range : 6000 ... 326999 =      6.000 ...   326.999 secs
# Ready.
# Reading 0 ... 320999  =      0.000 ...   320.999 secs...
# Not setting metadata
# 394 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 394 events and 1001 original time points ...
# 9 bad epochs dropped
# ✅ sub-01, run 27 done.
#
# Processing sub-01, run 28...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-28_meg.fif...
#     Range : 15000 ... 327999 =     15.000 ...   327.999 secs
# Ready.
# Reading 0 ... 312999  =      0.000 ...   312.999 secs...
# Not setting metadata
# 390 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 390 events and 1001 original time points ...
# 24 bad epochs dropped
# ✅ sub-01, run 28 done.
#
# Processing sub-01, run 29...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-29_meg.fif...
#     Range : 6000 ... 312999 =      6.000 ...   312.999 secs
# Ready.
# Reading 0 ... 306999  =      0.000 ...   306.999 secs...
# Not setting metadata
# 316 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 316 events and 1001 original time points ...
# 10 bad epochs dropped
# ✅ sub-01, run 29 done.
#
# Processing sub-01, run 30...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-30_meg.fif...
#     Range : 7000 ... 288999 =      7.000 ...   288.999 secs
# Ready.
# Reading 0 ... 281999  =      0.000 ...   281.999 secs...
# Not setting metadata
# 271 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 271 events and 1001 original time points ...
# 7 bad epochs dropped
# ✅ sub-01, run 30 done.
#
# Processing sub-01, run 31...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-31_meg.fif...
#     Range : 6000 ... 420999 =      6.000 ...   420.999 secs
# Ready.
# Reading 0 ... 414999  =      0.000 ...   414.999 secs...
# Not setting metadata
# 520 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 520 events and 1001 original time points ...
# 6 bad epochs dropped
# ✅ sub-01, run 31 done.
#
# Processing sub-01, run 32...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-32_meg.fif...
#     Range : 34000 ... 404999 =     34.000 ...   404.999 secs
# Ready.
# Reading 0 ... 370999  =      0.000 ...   370.999 secs...
# Not setting metadata
# 417 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 417 events and 1001 original time points ...
# 38 bad epochs dropped
# ✅ sub-01, run 32 done.
#
# Processing sub-01, run 33...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-33_meg.fif...
#     Range : 6000 ... 371999 =      6.000 ...   371.999 secs
# Ready.
# Reading 0 ... 365999  =      0.000 ...   365.999 secs...
# Not setting metadata
# 410 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 410 events and 1001 original time points ...
# 9 bad epochs dropped
# ✅ sub-01, run 33 done.
#
# Processing sub-01, run 34...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-34_meg.fif...
#     Range : 16000 ... 375999 =     16.000 ...   375.999 secs
# Ready.
# Reading 0 ... 359999  =      0.000 ...   359.999 secs...
# Not setting metadata
# 411 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 411 events and 1001 original time points ...
# 32 bad epochs dropped
# ✅ sub-01, run 34 done.
#
# Processing sub-01, run 35...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-35_meg.fif...
#     Range : 6000 ... 347999 =      6.000 ...   347.999 secs
# Ready.
# Reading 0 ... 341999  =      0.000 ...   341.999 secs...
# Not setting metadata
# 401 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 401 events and 1001 original time points ...
# 10 bad epochs dropped
# ✅ sub-01, run 35 done.
#
# Processing sub-01, run 36...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-36_meg.fif...
#     Range : 17000 ... 348999 =     17.000 ...   348.999 secs
# Ready.
# Reading 0 ... 331999  =      0.000 ...   331.999 secs...
# Not setting metadata
# 342 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 342 events and 1001 original time points ...
# 25 bad epochs dropped
# ✅ sub-01, run 36 done.
#
# Processing sub-01, run 37...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-37_meg.fif...
#     Range : 10000 ... 331999 =     10.000 ...   331.999 secs
# Ready.
# Reading 0 ... 321999  =      0.000 ...   321.999 secs...
# Not setting metadata
# 428 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 428 events and 1001 original time points ...
# 12 bad epochs dropped
# ✅ sub-01, run 37 done.
#
# Processing sub-01, run 38...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-38_meg.fif...
#     Range : 13000 ... 333999 =     13.000 ...   333.999 secs
# Ready.
# Reading 0 ... 320999  =      0.000 ...   320.999 secs...
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 347 events and 1001 original time points ...
# 17 bad epochs dropped
# ✅ sub-01, run 38 done.
#
# Processing sub-01, run 39...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-39_meg.fif...
#     Range : 11000 ... 316999 =     11.000 ...   316.999 secs
# Ready.
# Reading 0 ... 305999  =      0.000 ...   305.999 secs...
# Not setting metadata
# 380 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 380 events and 1001 original time points ...
# 16 bad epochs dropped
# ✅ sub-01, run 39 done.
#
# Processing sub-01, run 40...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-40_meg.fif...
#     Range : 6000 ... 292999 =      6.000 ...   292.999 secs
# Ready.
# Reading 0 ... 286999  =      0.000 ...   286.999 secs...
# Not setting metadata
# 305 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 305 events and 1001 original time points ...
# 5 bad epochs dropped
# ✅ sub-01, run 40 done.
#
# Processing sub-01, run 41...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-41_meg.fif...
#     Range : 10000 ... 410999 =     10.000 ...   410.999 secs
# Ready.
# Reading 0 ... 400999  =      0.000 ...   400.999 secs...
# Not setting metadata
# 472 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 472 events and 1001 original time points ...
# 21 bad epochs dropped
# ✅ sub-01, run 41 done.
#
# Processing sub-01, run 42...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-42_meg.fif...
#     Range : 12000 ... 382999 =     12.000 ...   382.999 secs
# Ready.
# Reading 0 ... 370999  =      0.000 ...   370.999 secs...
# Not setting metadata
# 424 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 424 events and 1001 original time points ...
# 16 bad epochs dropped
# ✅ sub-01, run 42 done.
#
# Processing sub-01, run 43...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-43_meg.fif...
#     Range : 14000 ... 377999 =     14.000 ...   377.999 secs
# Ready.
# Reading 0 ... 363999  =      0.000 ...   363.999 secs...
# Not setting metadata
# 383 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 383 events and 1001 original time points ...
# 17 bad epochs dropped
# ✅ sub-01, run 43 done.
#
# Processing sub-01, run 44...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-44_meg.fif...
#     Range : 8000 ... 372999 =      8.000 ...   372.999 secs
# Ready.
# Reading 0 ... 364999  =      0.000 ...   364.999 secs...
# Not setting metadata
# 357 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 357 events and 1001 original time points ...
# 9 bad epochs dropped
# ✅ sub-01, run 44 done.
#
# Processing sub-01, run 45...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-45_meg.fif...
#     Range : 7000 ... 347999 =      7.000 ...   347.999 secs
# Ready.
# Reading 0 ... 340999  =      0.000 ...   340.999 secs...
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 331 events and 1001 original time points ...
# 5 bad epochs dropped
# ✅ sub-01, run 45 done.
#
# Processing sub-01, run 46...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-46_meg.fif...
#     Range : 17000 ... 351999 =     17.000 ...   351.999 secs
# Ready.
# Reading 0 ... 334999  =      0.000 ...   334.999 secs...
# Not setting metadata
# 380 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 380 events and 1001 original time points ...
# 27 bad epochs dropped
# ✅ sub-01, run 46 done.
#
# Processing sub-01, run 47...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-47_meg.fif...
#     Range : 12000 ... 337999 =     12.000 ...   337.999 secs
# Ready.
# Reading 0 ... 325999  =      0.000 ...   325.999 secs...
# Not setting metadata
# 371 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 371 events and 1001 original time points ...
# 33 bad epochs dropped
# ✅ sub-01, run 47 done.
#
# Processing sub-01, run 48...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-48_meg.fif...
#     Range : 18000 ... 337999 =     18.000 ...   337.999 secs
# Ready.
# Reading 0 ... 319999  =      0.000 ...   319.999 secs...
# Not setting metadata
# 383 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 383 events and 1001 original time points ...
# 33 bad epochs dropped
# ✅ sub-01, run 48 done.
#
# Processing sub-01, run 49...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-49_meg.fif...
#     Range : 6000 ... 335999 =      6.000 ...   335.999 secs
# Ready.
# Reading 0 ... 329999  =      0.000 ...   329.999 secs...
# Not setting metadata
# 403 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 403 events and 1001 original time points ...
# 10 bad epochs dropped
# ✅ sub-01, run 49 done.
#
# Processing sub-01, run 50...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-50_meg.fif...
#     Range : 8000 ... 288999 =      8.000 ...   288.999 secs
# Ready.
# Reading 0 ... 280999  =      0.000 ...   280.999 secs...
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 346 events and 1001 original time points ...
# 19 bad epochs dropped
# ✅ sub-01, run 50 done.
#
# Processing sub-01, run 51...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-51_meg.fif...
#     Range : 28000 ... 413999 =     28.000 ...   413.999 secs
# Ready.
# Reading 0 ... 385999  =      0.000 ...   385.999 secs...
# Not setting metadata
# 485 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 485 events and 1001 original time points ...
# 32 bad epochs dropped
# ✅ sub-01, run 51 done.
#
# Processing sub-01, run 52...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-52_meg.fif...
#     Range : 23000 ... 372999 =     23.000 ...   372.999 secs
# Ready.
# Reading 0 ... 349999  =      0.000 ...   349.999 secs...
# Not setting metadata
# 401 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 401 events and 1001 original time points ...
# 30 bad epochs dropped
# ✅ sub-01, run 52 done.
#
# Processing sub-01, run 53...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-53_meg.fif...
#     Range : 6000 ... 369999 =      6.000 ...   369.999 secs
# Ready.
# Reading 0 ... 363999  =      0.000 ...   363.999 secs...
# Not setting metadata
# 415 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 415 events and 1001 original time points ...
# 7 bad epochs dropped
# ✅ sub-01, run 53 done.
#
# Processing sub-01, run 54...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-54_meg.fif...
#     Range : 9000 ... 359999 =      9.000 ...   359.999 secs
# Ready.
# Reading 0 ... 350999  =      0.000 ...   350.999 secs...
# Not setting metadata
# 402 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 402 events and 1001 original time points ...
# 21 bad epochs dropped
# ✅ sub-01, run 54 done.
#
# Processing sub-01, run 55...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-55_meg.fif...
#     Range : 8000 ... 349999 =      8.000 ...   349.999 secs
# Ready.
# Reading 0 ... 341999  =      0.000 ...   341.999 secs...
# Not setting metadata
# 396 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 396 events and 1001 original time points ...
# 10 bad epochs dropped
# ✅ sub-01, run 55 done.
#
# Processing sub-01, run 56...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-56_meg.fif...
#     Range : 14000 ... 366999 =     14.000 ...   366.999 secs
# Ready.
# Reading 0 ... 352999  =      0.000 ...   352.999 secs...
# Not setting metadata
# 427 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 427 events and 1001 original time points ...
# 18 bad epochs dropped
# ✅ sub-01, run 56 done.
#
# Processing sub-01, run 57...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-57_meg.fif...
#     Range : 7000 ... 326999 =      7.000 ...   326.999 secs
# Ready.
# Reading 0 ... 319999  =      0.000 ...   319.999 secs...
# Not setting metadata
# 358 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 358 events and 1001 original time points ...
# 10 bad epochs dropped
# ✅ sub-01, run 57 done.
#
# Processing sub-01, run 58...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-58_meg.fif...
#     Range : 12000 ... 334999 =     12.000 ...   334.999 secs
# Ready.
# Reading 0 ... 322999  =      0.000 ...   322.999 secs...
# Not setting metadata
# 329 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 329 events and 1001 original time points ...
# 25 bad epochs dropped
# ✅ sub-01, run 58 done.
#
# Processing sub-01, run 59...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-59_meg.fif...
#     Range : 12000 ... 320999 =     12.000 ...   320.999 secs
# Ready.
# Reading 0 ... 308999  =      0.000 ...   308.999 secs...
# Not setting metadata
# 336 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 336 events and 1001 original time points ...
# 17 bad epochs dropped
# ✅ sub-01, run 59 done.
#
# Processing sub-01, run 60...
# Opening raw data file ../SMN4Lang_data/ds004078/derivatives/preprocessed_data/sub-01/MEG/sub-01_task-RDR_run-60_meg.fif...
#     Range : 13000 ... 300999 =     13.000 ...   300.999 secs
# Ready.
# Reading 0 ... 287999  =      0.000 ...   287.999 secs...
# Not setting metadata
# 330 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 330 events and 1001 original time points ...
# 21 bad epochs dropped
# ✅ sub-01, run 60 done.
